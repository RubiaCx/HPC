# %%
import torch
import time
import gemm_cutlass
import pandas as pd
import matplotlib.pyplot as plt

# %%
device = "cuda:0"
torch.cuda.set_device(device)
dtype = torch.bfloat16

# %%
k0 = 1536
n0 = 6144
k1 = 6144
n1 = 1536

bias0 = torch.zeros((1, n0), dtype=dtype, device=device)
bias1 = torch.zeros((1, n1), dtype=dtype, device=device)

gemm0 = torch.randn((n0, k0), dtype=dtype, device=device)
gemm1 = torch.randn((n1, k1), dtype=dtype, device=device)

# m = batch_size * sequence_length
shapes = torch.load("ffn_inputShapes.pt")
m_values = set()  # 使用集合去重
for shape in shapes:
    m = shape[0] * shape[1]  
    m_values.add(m)

# %%
# 将集合转换为排序的列表
unique_m_values = sorted(list(m_values))

# 保存 m 值列表到文件
with open("unique_m_values.txt", "w") as f:
    for m in unique_m_values:
        f.write(f"{m}\n")

# %%
def benchmark(shapes, device, dtype, warmup_iters=10, test_iters=20):
    results = []

    for shape in shapes:
        input = torch.randn(torch.Size(shape), device=device, dtype=dtype)
        m = input.shape[0] * input.shape[1]
        print(f"Processing shape {shape} with m={m}")

        # Torch warm-up
        for _ in range(warmup_iters):
            _ = input @ gemm0.T
            _ = _ @ gemm1.T

        # Torch timing
        torch_times = []
        for _ in range(test_iters):
            torch.cuda.synchronize(device); start = time.time()
            torch_out0 = input @ gemm0.T
            torch_out1 = torch_out0 @ gemm1.T
            torch.cuda.synchronize(device); end = time.time()
            torch_times.append((end - start) * 1000)
        torch_time = sum(torch_times) / len(torch_times)

        # GemmBasic timing
        gemm_basic_times = []
        for _ in range(test_iters):
            torch.cuda.synchronize(device); start = time.time()
            cutlass_out0 = gemm_cutlass.GemmBasic(input, gemm0, bias0, None, None) # (m, n0) = (m, k0) X (k0, n0)
            cutlass_out1 = gemm_cutlass.GemmBasic(cutlass_out0, gemm1, bias1, None, None) # (m, n1) =  (m, n0) X (n0, n1)
            torch.cuda.synchronize(device); end = time.time()
            gemm_basic_times.append((end - start) * 1000)
        gemm_basic_time = sum(gemm_basic_times) / len(gemm_basic_times)
        gemm_basic_diff = (torch_out1.flatten() - cutlass_out1.flatten()).max().item()

        # GemmStreamK warm-up
        for _ in range(warmup_iters):
            cutlass_out0SK = gemm_cutlass.GemmStreamK(input, gemm0, bias0, None, None, None)
            cutlass_out1SK = gemm_cutlass.GemmStreamK(cutlass_out0SK, gemm1, bias1, None, None, None)

        # GemmStreamK timing
        gemm_streamk_times = []
        for _ in range(test_iters):
            torch.cuda.synchronize(device); start = time.time()
            cutlass_out0SK = gemm_cutlass.GemmStreamK(input, gemm0, bias0, None, None, None)
            cutlass_out1SK = gemm_cutlass.GemmStreamK(cutlass_out0SK, gemm1, bias1, None, None, None)
            torch.cuda.synchronize(device); end = time.time()
            gemm_streamk_times.append((end - start) * 1000)
        gemm_streamk_time = sum(gemm_streamk_times) / len(gemm_streamk_times)
        gemm_streamk_diff = (torch_out1.flatten() - cutlass_out1SK.flatten()).max().item()


        # Calculate speedup
        speedup_basic = torch_time / gemm_basic_time
        speedup_streamk = torch_time / gemm_streamk_time
        speedup_cutlass = gemm_basic_time / gemm_streamk_time
        # Store the results
        results.append({
            "m": m,
            "torch_time_ms": torch_time,
            "gemm_basic_time_ms": gemm_basic_time,
            "gemm_basic_diff": gemm_basic_diff,
            "speedup_basic": speedup_basic,
            "gemm_streamk_time_ms": gemm_streamk_time,
            "gemm_streamk_diff": gemm_streamk_diff,
            "speedup_streamk": speedup_streamk,
            "speedup_cutlass": speedup_cutlass,

        })

    return results

# %%
# Perform the benchmark
results = benchmark(shapes, device, dtype)
# Out:
# Processing shape tensor([  12,  154, 1536]) with m=1848
# Processing shape tensor([  12,  256, 1536]) with m=3072
# Processing shape tensor([  26,  154, 1536]) with m=4004
# Processing shape tensor([  26,  390, 1536]) with m=10140
# Processing shape tensor([  26,  405, 1536]) with m=10530
# Processing shape tensor([  26,  464, 1536]) with m=12064
# Processing shape tensor([  26,  527, 1536]) with m=13702
# Processing shape tensor([  26,  576, 1536]) with m=14976
# Processing shape tensor([  26,  700, 1536]) with m=18200
# Processing shape tensor([  26,  858, 1536]) with m=22308
# Processing shape tensor([  26, 1296, 1536]) with m=33696
# Processing shape tensor([  27,  154, 1536]) with m=4158
# Processing shape tensor([  27,  312, 1536]) with m=8424
# Processing shape tensor([  27,  350, 1536]) with m=9450
# Processing shape tensor([  27, 1196, 1536]) with m=32292
# Processing shape tensor([  28,  154, 1536]) with m=4312
# Processing shape tensor([  28,  312, 1536]) with m=8736
# Processing shape tensor([  28,  464, 1536]) with m=12992
# Processing shape tensor([  28,  700, 1536]) with m=19600
# Processing shape tensor([  28, 1032, 1536]) with m=28896
# Processing shape tensor([  28, 1196, 1536]) with m=33488
# Processing shape tensor([  29,  154, 1536]) with m=4466
# Processing shape tensor([  29,  312, 1536]) with m=9048
# Processing shape tensor([  29,  336, 1536]) with m=9744
# Processing shape tensor([  29,  510, 1536]) with m=14790
# Processing shape tensor([  29,  720, 1536]) with m=20880
# Processing shape tensor([  29,  777, 1536]) with m=22533
# Processing shape tensor([  29,  858, 1536]) with m=24882
# Processing shape tensor([  29,  943, 1536]) with m=27347
# Processing shape tensor([  29, 1008, 1536]) with m=29232
# Processing shape tensor([  30,  154, 1536]) with m=4620
# Processing shape tensor([  30,  299, 1536]) with m=8970
# Processing shape tensor([  30,  336, 1536]) with m=10080
# Processing shape tensor([  30,  405, 1536]) with m=12150
# Processing shape tensor([  30,  510, 1536]) with m=15300
# Processing shape tensor([  30,  527, 1536]) with m=15810
# Processing shape tensor([  30,  558, 1536]) with m=16740
# Processing shape tensor([  30,  720, 1536]) with m=21600
# Processing shape tensor([  30,  798, 1536]) with m=23940
# Processing shape tensor([  30,  858, 1536]) with m=25740
# Processing shape tensor([  30,  943, 1536]) with m=28290
# Processing shape tensor([  30, 1032, 1536]) with m=30960
# Processing shape tensor([  30, 1100, 1536]) with m=33000
# Processing shape tensor([  31,  154, 1536]) with m=4774
# Processing shape tensor([  31,  299, 1536]) with m=9269
# Processing shape tensor([  31,  312, 1536]) with m=9672
# Processing shape tensor([  31,  350, 1536]) with m=10850
# Processing shape tensor([  31,  390, 1536]) with m=12090
# Processing shape tensor([  31,  448, 1536]) with m=13888
# Processing shape tensor([  31,  464, 1536]) with m=14384
# Processing shape tensor([  31,  510, 1536]) with m=15810
# Processing shape tensor([  31,  920, 1536]) with m=28520
# Processing shape tensor([  31, 1008, 1536]) with m=31248
# Processing shape tensor([  31, 1100, 1536]) with m=34100
# Processing shape tensor([  32,  154, 1536]) with m=4928
# Processing shape tensor([  32,  350, 1536]) with m=11200
# Processing shape tensor([  32,  527, 1536]) with m=16864
# Processing shape tensor([  32,  576, 1536]) with m=18432
# Processing shape tensor([  32,  646, 1536]) with m=20672
# Processing shape tensor([  32,  665, 1536]) with m=21280
# Processing shape tensor([  32,  720, 1536]) with m=23040
# Processing shape tensor([  32,  798, 1536]) with m=25536
# Processing shape tensor([  32,  880, 1536]) with m=28160
# Processing shape tensor([  32,  920, 1536]) with m=29440
# Processing shape tensor([  32,  943, 1536]) with m=30176
# Processing shape tensor([  32,  966, 1536]) with m=30912
# Processing shape tensor([  32, 1008, 1536]) with m=32256
# Processing shape tensor([  32, 1032, 1536]) with m=33024
# Processing shape tensor([  33,  154, 1536]) with m=5082
# Processing shape tensor([  33,  299, 1536]) with m=9867
# Processing shape tensor([  33,  312, 1536]) with m=10296
# Processing shape tensor([  33,  350, 1536]) with m=11550
# Processing shape tensor([  33,  464, 1536]) with m=15312
# Processing shape tensor([  33,  510, 1536]) with m=16830
# Processing shape tensor([  33,  627, 1536]) with m=20691
# Processing shape tensor([  33,  646, 1536]) with m=21318
# Processing shape tensor([  33,  943, 1536]) with m=31119
# Processing shape tensor([  33, 1032, 1536]) with m=34056
# Processing shape tensor([  34,  154, 1536]) with m=5236
# Processing shape tensor([  34,  299, 1536]) with m=10166
# Processing shape tensor([  34,  350, 1536]) with m=11900
# Processing shape tensor([  34,  390, 1536]) with m=13260
# Processing shape tensor([  34,  405, 1536]) with m=13770
# Processing shape tensor([  34,  464, 1536]) with m=15776
# Processing shape tensor([  34,  594, 1536]) with m=20196
# Processing shape tensor([  34,  646, 1536]) with m=21964
# Processing shape tensor([  34,  665, 1536]) with m=22610
# Processing shape tensor([  34,  700, 1536]) with m=23800
# Processing shape tensor([  34,  720, 1536]) with m=24480
# Processing shape tensor([  34,  740, 1536]) with m=25160
# Processing shape tensor([  34,  798, 1536]) with m=27132
# Processing shape tensor([  34,  858, 1536]) with m=29172
# Processing shape tensor([  35,  154, 1536]) with m=5390
# Processing shape tensor([  35,  299, 1536]) with m=10465
# Processing shape tensor([  35,  350, 1536]) with m=12250
# Processing shape tensor([  35,  464, 1536]) with m=16240
# Processing shape tensor([  35,  480, 1536]) with m=16800
# Processing shape tensor([  35,  510, 1536]) with m=17850
# Processing shape tensor([  35,  527, 1536]) with m=18445
# Processing shape tensor([  35,  646, 1536]) with m=22610
# Processing shape tensor([  35,  665, 1536]) with m=23275
# Processing shape tensor([  35,  720, 1536]) with m=25200
# Processing shape tensor([  35,  798, 1536]) with m=27930
# Processing shape tensor([  35,  880, 1536]) with m=30800
# Processing shape tensor([  35,  920, 1536]) with m=32200
# Processing shape tensor([  35,  943, 1536]) with m=33005
# Processing shape tensor([  35, 1008, 1536]) with m=35280
# Processing shape tensor([  36,  154, 1536]) with m=5544
# Processing shape tensor([  36,  299, 1536]) with m=10764
# Processing shape tensor([  36,  350, 1536]) with m=12600
# Processing shape tensor([  36,  364, 1536]) with m=13104
# Processing shape tensor([  36,  420, 1536]) with m=15120
# Processing shape tensor([  36,  448, 1536]) with m=16128
# Processing shape tensor([  36,  464, 1536]) with m=16704
# Processing shape tensor([  36,  510, 1536]) with m=18360
# Processing shape tensor([  36,  527, 1536]) with m=18972
# Processing shape tensor([  36,  558, 1536]) with m=20088
# Processing shape tensor([  36,  576, 1536]) with m=20736
# Processing shape tensor([  36,  594, 1536]) with m=21384
# Processing shape tensor([  36,  627, 1536]) with m=22572
# Processing shape tensor([  36,  646, 1536]) with m=23256
# Processing shape tensor([  36,  665, 1536]) with m=23940
# Processing shape tensor([  36,  700, 1536]) with m=25200
# Processing shape tensor([  36,  798, 1536]) with m=28728
# Processing shape tensor([  36,  858, 1536]) with m=30888
# Processing shape tensor([  36,  943, 1536]) with m=33948
# Processing shape tensor([  37,  154, 1536]) with m=5698
# Processing shape tensor([  37,  299, 1536]) with m=11063
# Processing shape tensor([  37,  336, 1536]) with m=12432
# Processing shape tensor([  37,  350, 1536]) with m=12950
# Processing shape tensor([  37,  364, 1536]) with m=13468
# Processing shape tensor([  37,  390, 1536]) with m=14430
# Processing shape tensor([  37,  448, 1536]) with m=16576
# Processing shape tensor([  37,  464, 1536]) with m=17168
# Processing shape tensor([  37,  510, 1536]) with m=18870
# Processing shape tensor([  37,  527, 1536]) with m=19499
# Processing shape tensor([  37,  576, 1536]) with m=21312
# Processing shape tensor([  37,  594, 1536]) with m=21978
# Processing shape tensor([  37,  627, 1536]) with m=23199
# Processing shape tensor([  37,  740, 1536]) with m=27380
# Processing shape tensor([  37,  777, 1536]) with m=28749
# Processing shape tensor([  37,  798, 1536]) with m=29526
# Processing shape tensor([  37,  943, 1536]) with m=34891
# Processing shape tensor([  38,  154, 1536]) with m=5852
# Processing shape tensor([  38,  312, 1536]) with m=11856
# Processing shape tensor([  38,  364, 1536]) with m=13832
# Processing shape tensor([  38,  420, 1536]) with m=15960
# Processing shape tensor([  38,  464, 1536]) with m=17632
# Processing shape tensor([  38,  510, 1536]) with m=19380
# Processing shape tensor([  38,  527, 1536]) with m=20026
# Processing shape tensor([  38,  576, 1536]) with m=21888
# Processing shape tensor([  38,  594, 1536]) with m=22572
# Processing shape tensor([  38,  646, 1536]) with m=24548
# Processing shape tensor([  38,  665, 1536]) with m=25270
# Processing shape tensor([  38,  720, 1536]) with m=27360
# Processing shape tensor([  38,  777, 1536]) with m=29526
# Processing shape tensor([  38,  798, 1536]) with m=30324
# Processing shape tensor([  38,  858, 1536]) with m=32604
# Processing shape tensor([  38,  880, 1536]) with m=33440
# Processing shape tensor([  39,  154, 1536]) with m=6006
# Processing shape tensor([  39,  299, 1536]) with m=11661
# Processing shape tensor([  39,  312, 1536]) with m=12168
# Processing shape tensor([  39,  336, 1536]) with m=13104
# Processing shape tensor([  39,  510, 1536]) with m=19890
# Processing shape tensor([  39,  646, 1536]) with m=25194
# Processing shape tensor([  39,  665, 1536]) with m=25935
# Processing shape tensor([  39,  700, 1536]) with m=27300
# Processing shape tensor([  39,  720, 1536]) with m=28080
# Processing shape tensor([  39,  858, 1536]) with m=33462
# Processing shape tensor([  40,  154, 1536]) with m=6160
# Processing shape tensor([  40,  299, 1536]) with m=11960
# Processing shape tensor([  40,  312, 1536]) with m=12480
# Processing shape tensor([  40,  336, 1536]) with m=13440
# Processing shape tensor([  40,  364, 1536]) with m=14560
# Processing shape tensor([  40,  448, 1536]) with m=17920
# Processing shape tensor([  40,  464, 1536]) with m=18560
# Processing shape tensor([  40,  494, 1536]) with m=19760
# Processing shape tensor([  40,  527, 1536]) with m=21080
# Processing shape tensor([  40,  576, 1536]) with m=23040
# Processing shape tensor([  40,  627, 1536]) with m=25080
# Processing shape tensor([  40,  777, 1536]) with m=31080
# Processing shape tensor([  41,  154, 1536]) with m=6314
# Processing shape tensor([  41,  299, 1536]) with m=12259
# Processing shape tensor([  41,  312, 1536]) with m=12792
# Processing shape tensor([  41,  350, 1536]) with m=14350
# Processing shape tensor([  41,  448, 1536]) with m=18368
# Processing shape tensor([  41,  576, 1536]) with m=23616
# Processing shape tensor([  41,  646, 1536]) with m=26486
# Processing shape tensor([  41,  700, 1536]) with m=28700
# Processing shape tensor([  41,  720, 1536]) with m=29520
# Processing shape tensor([  41,  777, 1536]) with m=31857
# Processing shape tensor([  41,  798, 1536]) with m=32718
# Processing shape tensor([  42,  154, 1536]) with m=6468
# Processing shape tensor([  42,  299, 1536]) with m=12558
# Processing shape tensor([  42,  312, 1536]) with m=13104
# Processing shape tensor([  42,  350, 1536]) with m=14700
# Processing shape tensor([  42,  405, 1536]) with m=17010
# Processing shape tensor([  42,  448, 1536]) with m=18816
# Processing shape tensor([  42,  510, 1536]) with m=21420
# Processing shape tensor([  42,  527, 1536]) with m=22134
# Processing shape tensor([  42,  576, 1536]) with m=24192
# Processing shape tensor([  42,  594, 1536]) with m=24948
# Processing shape tensor([  42,  665, 1536]) with m=27930
# Processing shape tensor([  42,  700, 1536]) with m=29400
# Processing shape tensor([  42,  768, 1536]) with m=32256
# Processing shape tensor([  42,  777, 1536]) with m=32634
# Processing shape tensor([  42,  798, 1536]) with m=33516
# Processing shape tensor([  43,  154, 1536]) with m=6622
# Processing shape tensor([  43,  299, 1536]) with m=12857
# Processing shape tensor([  43,  312, 1536]) with m=13416
# Processing shape tensor([  43,  364, 1536]) with m=15652
# Processing shape tensor([  43,  405, 1536]) with m=17415
# Processing shape tensor([  43,  448, 1536]) with m=19264
# Processing shape tensor([  43,  464, 1536]) with m=19952
# Processing shape tensor([  43,  576, 1536]) with m=24768
# Processing shape tensor([  43,  594, 1536]) with m=25542
# Processing shape tensor([  43,  627, 1536]) with m=26961
# Processing shape tensor([  43,  646, 1536]) with m=27778
# Processing shape tensor([  43,  700, 1536]) with m=30100
# Processing shape tensor([  43,  777, 1536]) with m=33411
# Processing shape tensor([  43,  798, 1536]) with m=34314
# Processing shape tensor([  44,  154, 1536]) with m=6776
# Processing shape tensor([  44,  299, 1536]) with m=13156
# Processing shape tensor([  44,  390, 1536]) with m=17160
# Processing shape tensor([  44,  405, 1536]) with m=17820
# Processing shape tensor([  44,  448, 1536]) with m=19712
# Processing shape tensor([  44,  464, 1536]) with m=20416
# Processing shape tensor([  44,  527, 1536]) with m=23188
# Processing shape tensor([  44,  558, 1536]) with m=24552
# Processing shape tensor([  44,  576, 1536]) with m=25344
# Processing shape tensor([  44,  627, 1536]) with m=27588
# Processing shape tensor([  44,  646, 1536]) with m=28424
# Processing shape tensor([  44,  720, 1536]) with m=31680
# Processing shape tensor([  45,  154, 1536]) with m=6930
# Processing shape tensor([  45,  312, 1536]) with m=14040
# Processing shape tensor([  45,  350, 1536]) with m=15750
# Processing shape tensor([  45,  510, 1536]) with m=22950
# Processing shape tensor([  45,  527, 1536]) with m=23715
# Processing shape tensor([  45,  576, 1536]) with m=25920
# Processing shape tensor([  45,  627, 1536]) with m=28215
# Processing shape tensor([  45,  646, 1536]) with m=29070
# Processing shape tensor([  45,  665, 1536]) with m=29925
# Processing shape tensor([  45,  720, 1536]) with m=32400
# Processing shape tensor([  45,  777, 1536]) with m=34965
# Processing shape tensor([  46,  154, 1536]) with m=7084
# Processing shape tensor([  46,  299, 1536]) with m=13754
# Processing shape tensor([  46,  312, 1536]) with m=14352
# Processing shape tensor([  46,  405, 1536]) with m=18630
# Processing shape tensor([  46,  420, 1536]) with m=19320
# Processing shape tensor([  46,  510, 1536]) with m=23460
# Processing shape tensor([  46,  527, 1536]) with m=24242
# Processing shape tensor([  46,  576, 1536]) with m=26496
# Processing shape tensor([  46,  594, 1536]) with m=27324
# Processing shape tensor([  46,  665, 1536]) with m=30590
# Processing shape tensor([  46,  700, 1536]) with m=32200
# Processing shape tensor([  46,  740, 1536]) with m=34040
# Processing shape tensor([  47,  154, 1536]) with m=7238
# Processing shape tensor([  47,  350, 1536]) with m=16450
# Processing shape tensor([  47,  364, 1536]) with m=17108
# Processing shape tensor([  47,  390, 1536]) with m=18330
# Processing shape tensor([  47,  405, 1536]) with m=19035
# Processing shape tensor([  47,  464, 1536]) with m=21808
# Processing shape tensor([  47,  527, 1536]) with m=24769
# Processing shape tensor([  47,  594, 1536]) with m=27918
# Processing shape tensor([  47,  627, 1536]) with m=29469
# Processing shape tensor([  47,  700, 1536]) with m=32900
# Processing shape tensor([  47,  720, 1536]) with m=33840
# Processing shape tensor([  48,  154, 1536]) with m=7392
# Processing shape tensor([  48,  299, 1536]) with m=14352
# Processing shape tensor([  48,  312, 1536]) with m=14976
# Processing shape tensor([  48,  336, 1536]) with m=16128
# Processing shape tensor([  48,  350, 1536]) with m=16800
# Processing shape tensor([  48,  364, 1536]) with m=17472
# Processing shape tensor([  48,  390, 1536]) with m=18720
# Processing shape tensor([  48,  405, 1536]) with m=19440
# Processing shape tensor([  48,  420, 1536]) with m=20160
# Processing shape tensor([  48,  448, 1536]) with m=21504
# Processing shape tensor([  48,  464, 1536]) with m=22272
# Processing shape tensor([  48,  510, 1536]) with m=24480
# Processing shape tensor([  48,  527, 1536]) with m=25296
# Processing shape tensor([  48,  558, 1536]) with m=26784
# Processing shape tensor([  48,  576, 1536]) with m=27648
# Processing shape tensor([  48,  594, 1536]) with m=28512
# Processing shape tensor([  48,  627, 1536]) with m=30096
# Processing shape tensor([  48,  646, 1536]) with m=31008
# Processing shape tensor([  48,  665, 1536]) with m=31920
# Processing shape tensor([  48,  700, 1536]) with m=33600
# Processing shape tensor([  48,  720, 1536]) with m=34560
# Processing shape tensor([  49,  154, 1536]) with m=7546
# Processing shape tensor([  49,  299, 1536]) with m=14651
# Processing shape tensor([  49,  312, 1536]) with m=15288
# Processing shape tensor([  49,  350, 1536]) with m=17150
# Processing shape tensor([  49,  364, 1536]) with m=17836
# Processing shape tensor([  49,  374, 1536]) with m=18326
# Processing shape tensor([  49,  390, 1536]) with m=19110
# Processing shape tensor([  49,  405, 1536]) with m=19845
# Processing shape tensor([  49,  420, 1536]) with m=20580
# Processing shape tensor([  49,  448, 1536]) with m=21952
# Processing shape tensor([  49,  450, 1536]) with m=22050
# Processing shape tensor([  49,  464, 1536]) with m=22736
# Processing shape tensor([  49,  510, 1536]) with m=24990
# Processing shape tensor([  49,  527, 1536]) with m=25823
# Processing shape tensor([  49,  558, 1536]) with m=27342
# Processing shape tensor([  49,  576, 1536]) with m=28224
# Processing shape tensor([  49,  594, 1536]) with m=29106
# Processing shape tensor([  49,  627, 1536]) with m=30723
# Processing shape tensor([  49,  646, 1536]) with m=31654
# Processing shape tensor([  49,  665, 1536]) with m=32585
# Processing shape tensor([  50,  154, 1536]) with m=7700
# Processing shape tensor([  50,  299, 1536]) with m=14950
# Processing shape tensor([  50,  312, 1536]) with m=15600
# Processing shape tensor([  50,  336, 1536]) with m=16800
# Processing shape tensor([  50,  350, 1536]) with m=17500
# Processing shape tensor([  50,  364, 1536]) with m=18200
# Processing shape tensor([  50,  405, 1536]) with m=20250
# Processing shape tensor([  50,  510, 1536]) with m=25500
# Processing shape tensor([  50,  527, 1536]) with m=26350
# Processing shape tensor([  50,  576, 1536]) with m=28800
# Processing shape tensor([  50,  594, 1536]) with m=29700
# Processing shape tensor([  50,  646, 1536]) with m=32300
# Processing shape tensor([  51,  154, 1536]) with m=7854
# Processing shape tensor([  51,  405, 1536]) with m=20655
# Processing shape tensor([  51,  464, 1536]) with m=23664
# Processing shape tensor([  51,  510, 1536]) with m=26010
# Processing shape tensor([  51,  527, 1536]) with m=26877
# Processing shape tensor([  51,  576, 1536]) with m=29376
# Processing shape tensor([  51,  594, 1536]) with m=30294
# Processing shape tensor([  51,  627, 1536]) with m=31977
# Processing shape tensor([  51,  665, 1536]) with m=33915
# Processing shape tensor([  52,  154, 1536]) with m=8008
# Processing shape tensor([  52,  299, 1536]) with m=15548
# Processing shape tensor([  52,  312, 1536]) with m=16224
# Processing shape tensor([  52,  390, 1536]) with m=20280
# Processing shape tensor([  52,  448, 1536]) with m=23296
# Processing shape tensor([  52,  464, 1536]) with m=24128
# Processing shape tensor([  52,  527, 1536]) with m=27404
# Processing shape tensor([  52,  576, 1536]) with m=29952
# Processing shape tensor([  52,  646, 1536]) with m=33592
# Processing shape tensor([  53,  154, 1536]) with m=8162
# Processing shape tensor([  53,  299, 1536]) with m=15847
# Processing shape tensor([  53,  364, 1536]) with m=19292
# Processing shape tensor([  53,  390, 1536]) with m=20670
# Processing shape tensor([  53,  420, 1536]) with m=22260
# Processing shape tensor([  53,  510, 1536]) with m=27030
# Processing shape tensor([  53,  576, 1536]) with m=30528
# Processing shape tensor([  53,  646, 1536]) with m=34238
# Processing shape tensor([  54,  154, 1536]) with m=8316
# Processing shape tensor([  54,  299, 1536]) with m=16146
# Processing shape tensor([  54,  336, 1536]) with m=18144
# Processing shape tensor([  54,  350, 1536]) with m=18900
# Processing shape tensor([  54,  390, 1536]) with m=21060
# Processing shape tensor([  54,  405, 1536]) with m=21870
# Processing shape tensor([  54,  420, 1536]) with m=22680
# Processing shape tensor([  54,  464, 1536]) with m=25056
# Processing shape tensor([  54,  558, 1536]) with m=30132
# Processing shape tensor([  54,  594, 1536]) with m=32076
# Processing shape tensor([  55,  154, 1536]) with m=8470
# Processing shape tensor([  55,  299, 1536]) with m=16445
# Processing shape tensor([  55,  312, 1536]) with m=17160
# Processing shape tensor([  55,  350, 1536]) with m=19250
# Processing shape tensor([  55,  405, 1536]) with m=22275
# Processing shape tensor([  55,  464, 1536]) with m=25520
# Processing shape tensor([  55,  510, 1536]) with m=28050
# Processing shape tensor([  55,  627, 1536]) with m=34485
# Processing shape tensor([  56,  154, 1536]) with m=8624
# Processing shape tensor([  56,  299, 1536]) with m=16744
# Processing shape tensor([  56,  312, 1536]) with m=17472
# Processing shape tensor([  56,  336, 1536]) with m=18816
# Processing shape tensor([  56,  350, 1536]) with m=19600
# Processing shape tensor([  56,  405, 1536]) with m=22680
# Processing shape tensor([  56,  464, 1536]) with m=25984
# Processing shape tensor([  56,  527, 1536]) with m=29512
# Processing shape tensor([  56,  576, 1536]) with m=32256
# Processing shape tensor([  56,  594, 1536]) with m=33264
# Processing shape tensor([  57,  154, 1536]) with m=8778
# Processing shape tensor([  57,  312, 1536]) with m=17784
# Processing shape tensor([  57,  364, 1536]) with m=20748
# Processing shape tensor([  57,  405, 1536]) with m=23085
# Processing shape tensor([  57,  420, 1536]) with m=23940
# Processing shape tensor([  57,  464, 1536]) with m=26448
# Processing shape tensor([  57,  527, 1536]) with m=30039
# Processing shape tensor([  57,  594, 1536]) with m=33858
# Processing shape tensor([  58,  154, 1536]) with m=8932
# Processing shape tensor([  58,  299, 1536]) with m=17342
# Processing shape tensor([  58,  312, 1536]) with m=18096
# Processing shape tensor([  58,  350, 1536]) with m=20300
# Processing shape tensor([  58,  364, 1536]) with m=21112
# Processing shape tensor([  58,  464, 1536]) with m=26912
# Processing shape tensor([  58,  527, 1536]) with m=30566
# Processing shape tensor([  58,  576, 1536]) with m=33408
# Processing shape tensor([  58,  594, 1536]) with m=34452
# Processing shape tensor([  59,  154, 1536]) with m=9086
# Processing shape tensor([  59,  299, 1536]) with m=17641
# Processing shape tensor([  59,  312, 1536]) with m=18408
# Processing shape tensor([  59,  350, 1536]) with m=20650
# Processing shape tensor([  59,  405, 1536]) with m=23895
# Processing shape tensor([  59,  420, 1536]) with m=24780
# Processing shape tensor([  59,  448, 1536]) with m=26432
# Processing shape tensor([  59,  464, 1536]) with m=27376
# Processing shape tensor([  60,  154, 1536]) with m=9240
# Processing shape tensor([  60,  312, 1536]) with m=18720
# Processing shape tensor([  60,  350, 1536]) with m=21000
# Processing shape tensor([  60,  364, 1536]) with m=21840
# Processing shape tensor([  60,  390, 1536]) with m=23400
# Processing shape tensor([  60,  448, 1536]) with m=26880
# Processing shape tensor([  60,  464, 1536]) with m=27840
# Processing shape tensor([  60,  527, 1536]) with m=31620
# Processing shape tensor([  60,  576, 1536]) with m=34560
# Processing shape tensor([  61,  154, 1536]) with m=9394
# Processing shape tensor([  61,  312, 1536]) with m=19032
# Processing shape tensor([  61,  336, 1536]) with m=20496
# Processing shape tensor([  61,  350, 1536]) with m=21350
# Processing shape tensor([  61,  390, 1536]) with m=23790
# Processing shape tensor([  61,  405, 1536]) with m=24705
# Processing shape tensor([  61,  448, 1536]) with m=27328
# Processing shape tensor([  61,  464, 1536]) with m=28304
# Processing shape tensor([  61,  510, 1536]) with m=31110
# Processing shape tensor([  61,  527, 1536]) with m=32147
# Processing shape tensor([  62,  154, 1536]) with m=9548
# Processing shape tensor([  62,  299, 1536]) with m=18538
# Processing shape tensor([  62,  312, 1536]) with m=19344
# Processing shape tensor([  62,  350, 1536]) with m=21700
# Processing shape tensor([  62,  405, 1536]) with m=25110
# Processing shape tensor([  62,  420, 1536]) with m=26040
# Processing shape tensor([  63,  154, 1536]) with m=9702
# Processing shape tensor([  63,  312, 1536]) with m=19656
# Processing shape tensor([  63,  350, 1536]) with m=22050
# Processing shape tensor([  63,  364, 1536]) with m=22932
# Processing shape tensor([  63,  405, 1536]) with m=25515
# Processing shape tensor([  63,  448, 1536]) with m=28224
# Processing shape tensor([  63,  510, 1536]) with m=32130
# Processing shape tensor([  63,  527, 1536]) with m=33201
# Processing shape tensor([  64,  154, 1536]) with m=9856
# Processing shape tensor([  64,  299, 1536]) with m=19136
# Processing shape tensor([  64,  312, 1536]) with m=19968
# Processing shape tensor([  64,  336, 1536]) with m=21504
# Processing shape tensor([  64,  364, 1536]) with m=23296
# Processing shape tensor([  64,  405, 1536]) with m=25920
# Processing shape tensor([  64,  420, 1536]) with m=26880
# Processing shape tensor([  64,  510, 1536]) with m=32640
# Processing shape tensor([  64,  527, 1536]) with m=33728
# Processing shape tensor([  65,  154, 1536]) with m=10010
# Processing shape tensor([  65,  299, 1536]) with m=19435
# Processing shape tensor([  65,  312, 1536]) with m=20280
# Processing shape tensor([  65,  448, 1536]) with m=29120
# Processing shape tensor([  65,  510, 1536]) with m=33150
# Processing shape tensor([  65,  527, 1536]) with m=34255
# Processing shape tensor([  66,  154, 1536]) with m=10164
# Processing shape tensor([  66,  312, 1536]) with m=20592
# Processing shape tensor([  66,  405, 1536]) with m=26730
# Processing shape tensor([  66,  448, 1536]) with m=29568
# Processing shape tensor([  66,  510, 1536]) with m=33660
# Processing shape tensor([  67,  154, 1536]) with m=10318
# Processing shape tensor([  67,  299, 1536]) with m=20033
# Processing shape tensor([  67,  312, 1536]) with m=20904
# Processing shape tensor([  67,  336, 1536]) with m=22512
# Processing shape tensor([  67,  350, 1536]) with m=23450
# Processing shape tensor([  67,  405, 1536]) with m=27135
# Processing shape tensor([  67,  420, 1536]) with m=28140
# Processing shape tensor([  67,  448, 1536]) with m=30016
# Processing shape tensor([  67,  464, 1536]) with m=31088
# Processing shape tensor([  68,  154, 1536]) with m=10472
# Processing shape tensor([  68,  299, 1536]) with m=20332
# Processing shape tensor([  68,  312, 1536]) with m=21216
# Processing shape tensor([  68,  364, 1536]) with m=24752
# Processing shape tensor([  68,  390, 1536]) with m=26520
# Processing shape tensor([  68,  448, 1536]) with m=30464
# Processing shape tensor([  68,  464, 1536]) with m=31552
# Processing shape tensor([  68,  480, 1536]) with m=32640
# Processing shape tensor([  68,  510, 1536]) with m=34680
# Processing shape tensor([  69,  154, 1536]) with m=10626
# Processing shape tensor([  69,  350, 1536]) with m=24150
# Processing shape tensor([  69,  364, 1536]) with m=25116
# Processing shape tensor([  69,  464, 1536]) with m=32016
# Processing shape tensor([  70,  154, 1536]) with m=10780
# Processing shape tensor([  70,  299, 1536]) with m=20930
# Processing shape tensor([  70,  336, 1536]) with m=23520
# Processing shape tensor([  70,  350, 1536]) with m=24500
# Processing shape tensor([  70,  405, 1536]) with m=28350
# Processing shape tensor([  70,  464, 1536]) with m=32480
# Processing shape tensor([  71,  154, 1536]) with m=10934
# Processing shape tensor([  71,  336, 1536]) with m=23856
# Processing shape tensor([  71,  364, 1536]) with m=25844
# Processing shape tensor([  71,  405, 1536]) with m=28755
# Processing shape tensor([  72,  154, 1536]) with m=11088
# Processing shape tensor([  72,  299, 1536]) with m=21528
# Processing shape tensor([  72,  350, 1536]) with m=25200
# Processing shape tensor([  72,  390, 1536]) with m=28080
# Processing shape tensor([  72,  464, 1536]) with m=33408
# Processing shape tensor([  73,  154, 1536]) with m=11242
# Processing shape tensor([  73,  299, 1536]) with m=21827
# Processing shape tensor([  73,  336, 1536]) with m=24528
# Processing shape tensor([  73,  350, 1536]) with m=25550
# Processing shape tensor([  73,  364, 1536]) with m=26572
# Processing shape tensor([  73,  448, 1536]) with m=32704
# Processing shape tensor([  74,  154, 1536]) with m=11396
# Processing shape tensor([  74,  299, 1536]) with m=22126
# Processing shape tensor([  74,  312, 1536]) with m=23088
# Processing shape tensor([  74,  350, 1536]) with m=25900
# Processing shape tensor([  74,  364, 1536]) with m=26936
# Processing shape tensor([  74,  420, 1536]) with m=31080
# Processing shape tensor([  74,  448, 1536]) with m=33152
# Processing shape tensor([  74,  464, 1536]) with m=34336
# Processing shape tensor([  75,  154, 1536]) with m=11550
# Processing shape tensor([  75,  299, 1536]) with m=22425
# Processing shape tensor([  75,  350, 1536]) with m=26250
# Processing shape tensor([  75,  364, 1536]) with m=27300
# Processing shape tensor([  75,  405, 1536]) with m=30375
# Processing shape tensor([  75,  420, 1536]) with m=31500
# Processing shape tensor([  75,  448, 1536]) with m=33600
# Processing shape tensor([  76,  154, 1536]) with m=11704
# Processing shape tensor([  76,  299, 1536]) with m=22724
# Processing shape tensor([  76,  336, 1536]) with m=25536
# Processing shape tensor([  76,  350, 1536]) with m=26600
# Processing shape tensor([  76,  364, 1536]) with m=27664
# Processing shape tensor([  76,  405, 1536]) with m=30780
# Processing shape tensor([  77,  154, 1536]) with m=11858
# Processing shape tensor([  77,  336, 1536]) with m=25872
# Processing shape tensor([  77,  364, 1536]) with m=28028
# Processing shape tensor([  77,  448, 1536]) with m=34496
# Processing shape tensor([  78,  154, 1536]) with m=12012
# Processing shape tensor([  78,  364, 1536]) with m=28392
# Processing shape tensor([  78,  390, 1536]) with m=30420
# Processing shape tensor([  78,  391, 1536]) with m=30498
# Processing shape tensor([  78,  405, 1536]) with m=31590
# Processing shape tensor([  79,  154, 1536]) with m=12166
# Processing shape tensor([  79,  299, 1536]) with m=23621
# Processing shape tensor([  79,  390, 1536]) with m=30810
# Processing shape tensor([  79,  420, 1536]) with m=33180
# Processing shape tensor([  80,  154, 1536]) with m=12320
# Processing shape tensor([  80,  312, 1536]) with m=24960
# Processing shape tensor([  80,  336, 1536]) with m=26880
# Processing shape tensor([  80,  350, 1536]) with m=28000
# Processing shape tensor([  80,  364, 1536]) with m=29120
# Processing shape tensor([  80,  405, 1536]) with m=32400
# Processing shape tensor([  81,  154, 1536]) with m=12474
# Processing shape tensor([  81,  299, 1536]) with m=24219
# Processing shape tensor([  81,  350, 1536]) with m=28350
# Processing shape tensor([  82,  154, 1536]) with m=12628
# Processing shape tensor([  82,  299, 1536]) with m=24518
# Processing shape tensor([  82,  312, 1536]) with m=25584
# Processing shape tensor([  82,  405, 1536]) with m=33210
# Processing shape tensor([  83,  154, 1536]) with m=12782
# Processing shape tensor([  83,  312, 1536]) with m=25896
# Processing shape tensor([  83,  364, 1536]) with m=30212
# Processing shape tensor([  83,  405, 1536]) with m=33615
# Processing shape tensor([  84,  154, 1536]) with m=12936
# Processing shape tensor([  84,  299, 1536]) with m=25116
# Processing shape tensor([  84,  336, 1536]) with m=28224
# Processing shape tensor([  84,  350, 1536]) with m=29400
# Processing shape tensor([  85,  154, 1536]) with m=13090
# Processing shape tensor([  85,  299, 1536]) with m=25415
# Processing shape tensor([  85,  336, 1536]) with m=28560
# Processing shape tensor([  85,  350, 1536]) with m=29750
# Processing shape tensor([  85,  364, 1536]) with m=30940
# Processing shape tensor([  85,  390, 1536]) with m=33150
# Processing shape tensor([  86,  154, 1536]) with m=13244
# Processing shape tensor([  86,  299, 1536]) with m=25714
# Processing shape tensor([  86,  312, 1536]) with m=26832
# Processing shape tensor([  86,  336, 1536]) with m=28896
# Processing shape tensor([  86,  350, 1536]) with m=30100
# Processing shape tensor([  86,  364, 1536]) with m=31304
# Processing shape tensor([  87,  154, 1536]) with m=13398
# Processing shape tensor([  87,  299, 1536]) with m=26013
# Processing shape tensor([  87,  312, 1536]) with m=27144
# Processing shape tensor([  87,  350, 1536]) with m=30450
# Processing shape tensor([  88,  154, 1536]) with m=13552
# Processing shape tensor([  88,  299, 1536]) with m=26312
# Processing shape tensor([  88,  350, 1536]) with m=30800
# Processing shape tensor([  88,  364, 1536]) with m=32032
# Processing shape tensor([  88,  390, 1536]) with m=34320
# Processing shape tensor([  89,  154, 1536]) with m=13706
# Processing shape tensor([  89,  299, 1536]) with m=26611
# Processing shape tensor([  89,  312, 1536]) with m=27768
# Processing shape tensor([  90,  154, 1536]) with m=13860
# Processing shape tensor([  90,  299, 1536]) with m=26910
# Processing shape tensor([  90,  312, 1536]) with m=28080
# Processing shape tensor([  90,  350, 1536]) with m=31500
# Processing shape tensor([  90,  364, 1536]) with m=32760
# Processing shape tensor([  91,  154, 1536]) with m=14014
# Processing shape tensor([  91,  299, 1536]) with m=27209
# Processing shape tensor([  92,  154, 1536]) with m=14168
# Processing shape tensor([  92,  299, 1536]) with m=27508
# Processing shape tensor([  92,  312, 1536]) with m=28704
# Processing shape tensor([  92,  336, 1536]) with m=30912
# Processing shape tensor([  92,  350, 1536]) with m=32200
# Processing shape tensor([  93,  154, 1536]) with m=14322
# Processing shape tensor([  93,  299, 1536]) with m=27807
# Processing shape tensor([  93,  312, 1536]) with m=29016
# Processing shape tensor([  94,  154, 1536]) with m=14476
# Processing shape tensor([  94,  299, 1536]) with m=28106
# Processing shape tensor([  94,  312, 1536]) with m=29328
# Processing shape tensor([  94,  350, 1536]) with m=32900
# Processing shape tensor([  95,  154, 1536]) with m=14630
# Processing shape tensor([  95,  312, 1536]) with m=29640
# Processing shape tensor([  95,  350, 1536]) with m=33250
# Processing shape tensor([  96,  154, 1536]) with m=14784
# Processing shape tensor([  96,  299, 1536]) with m=28704
# Processing shape tensor([  96,  300, 1536]) with m=28800
# Processing shape tensor([  96,  312, 1536]) with m=29952
# Processing shape tensor([  96,  336, 1536]) with m=32256
# Processing shape tensor([  96,  350, 1536]) with m=33600
# Processing shape tensor([  97,  154, 1536]) with m=14938
# Processing shape tensor([  97,  299, 1536]) with m=29003
# Processing shape tensor([  97,  312, 1536]) with m=30264
# Processing shape tensor([  97,  336, 1536]) with m=32592
# Processing shape tensor([  97,  350, 1536]) with m=33950
# Processing shape tensor([  98,  154, 1536]) with m=15092
# Processing shape tensor([  98,  299, 1536]) with m=29302
# Processing shape tensor([  98,  336, 1536]) with m=32928
# Processing shape tensor([  98,  350, 1536]) with m=34300
# Processing shape tensor([  99,  154, 1536]) with m=15246
# Processing shape tensor([  99,  299, 1536]) with m=29601
# Processing shape tensor([  99,  312, 1536]) with m=30888
# Processing shape tensor([ 100,  154, 1536]) with m=15400
# Processing shape tensor([ 100,  299, 1536]) with m=29900
# Processing shape tensor([ 100,  312, 1536]) with m=31200
# Processing shape tensor([ 100,  336, 1536]) with m=33600
# Processing shape tensor([ 101,  154, 1536]) with m=15554
# Processing shape tensor([ 101,  299, 1536]) with m=30199
# Processing shape tensor([ 101,  312, 1536]) with m=31512
# Processing shape tensor([ 102,  154, 1536]) with m=15708
# Processing shape tensor([ 102,  299, 1536]) with m=30498
# Processing shape tensor([ 102,  312, 1536]) with m=31824
# Processing shape tensor([ 102,  315, 1536]) with m=32130
# Processing shape tensor([ 103,  154, 1536]) with m=15862
# Processing shape tensor([ 103,  299, 1536]) with m=30797
# Processing shape tensor([ 104,  154, 1536]) with m=16016
# Processing shape tensor([ 104,  299, 1536]) with m=31096
# Processing shape tensor([ 104,  312, 1536]) with m=32448
# Processing shape tensor([ 105,  154, 1536]) with m=16170
# Processing shape tensor([ 105,  299, 1536]) with m=31395
# Processing shape tensor([ 105,  312, 1536]) with m=32760
# Processing shape tensor([ 106,  154, 1536]) with m=16324
# Processing shape tensor([ 106,  299, 1536]) with m=31694
# Processing shape tensor([ 106,  312, 1536]) with m=33072
# Processing shape tensor([ 107,  154, 1536]) with m=16478
# Processing shape tensor([ 107,  299, 1536]) with m=31993
# Processing shape tensor([ 108,  154, 1536]) with m=16632
# Processing shape tensor([ 108,  299, 1536]) with m=32292
# Processing shape tensor([ 108,  312, 1536]) with m=33696
# Processing shape tensor([ 109,  154, 1536]) with m=16786
# Processing shape tensor([ 109,  299, 1536]) with m=32591
# Processing shape tensor([ 110,  154, 1536]) with m=16940
# Processing shape tensor([ 110,  299, 1536]) with m=32890
# Processing shape tensor([ 111,  154, 1536]) with m=17094
# Processing shape tensor([ 111,  299, 1536]) with m=33189
# Processing shape tensor([ 112,  154, 1536]) with m=17248
# Processing shape tensor([ 112,  299, 1536]) with m=33488
# Processing shape tensor([ 113,  154, 1536]) with m=17402
# Processing shape tensor([ 113,  299, 1536]) with m=33787
# Processing shape tensor([ 114,  154, 1536]) with m=17556
# Processing shape tensor([ 114,  299, 1536]) with m=34086
# Processing shape tensor([ 115,  154, 1536]) with m=17710
# Processing shape tensor([ 115,  299, 1536]) with m=34385
# Processing shape tensor([ 116,  154, 1536]) with m=17864
# Processing shape tensor([ 116,  299, 1536]) with m=34684
# Processing shape tensor([ 117,  154, 1536]) with m=18018
# Processing shape tensor([ 117,  299, 1536]) with m=34983
# Processing shape tensor([ 118,  154, 1536]) with m=18172
# Processing shape tensor([ 118,  299, 1536]) with m=35282
# Processing shape tensor([ 119,  154, 1536]) with m=18326
# Processing shape tensor([ 119,  299, 1536]) with m=35581
# Processing shape tensor([ 120,  154, 1536]) with m=18480
# Processing shape tensor([ 120,  299, 1536]) with m=35880
# Processing shape tensor([ 120,  300, 1536]) with m=36000
# Processing shape tensor([ 125,  154, 1536]) with m=19250
# Processing shape tensor([ 125,  288, 1536]) with m=36000

# %%
# Convert results to DataFrame
df_results = pd.DataFrame(results)

# Save results to a txt file
df_results.to_csv("benchmark_results_0.txt", index=False, sep='\t')

print("Benchmark completed. Results saved to benchmark_results.txt")
# Out:
# Benchmark completed. Results saved to benchmark_results.txt

# %%
data = pd.read_csv('benchmark_results_0.txt', sep='\t')
df = pd.DataFrame(data)
index = range(len(df))
df = df.sort_values(by="m", ascending=True)

# %%
df = df.sort_values(by="m", ascending=True)

# %%
plt.figure(figsize=(12, 4))
bar_width = 0.35
plt.scatter(index, df["torch_time_ms"], label="Torch Time (ms)", s=10)
plt.scatter(index, df["gemm_basic_time_ms"], label="GemmBasic Time (ms)", s=10)
plt.scatter(index, df["gemm_streamk_time_ms"], label="GemmStreamK Time (ms)", s=10)

# plt.bar(index , df["torch_time_ms"], label="Torch Time (ms)")
# plt.bar(index , df["gemm_basic_time_ms"], label="GemmBasic Time (ms)")
# plt.bar(index , df["gemm_streamk_time_ms"], label="GemmStreamK Time (ms)")
plt.title("Time")
plt.xlabel("Index")
plt.ylabel("Time (ms)")
plt.legend()
plt.show()

# %%
mask = df["speedup_cutlass"] > 1

plt.figure(figsize=(12, 4))
bar_width = 0.35
index = range(len(df))

colors = ["red" if is_above_1 else "royalblue" for is_above_1 in mask]

plt.bar(index, df["speedup_cutlass"], width=bar_width, color=colors)
plt.title("CUTLASS Basic/StreamK (Red for Speedup > 1)", fontsize=18, fontweight='bold')
plt.ylabel("Speedup", fontsize=14)
plt.xlabel("Index")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 4))
bar_width = 0.35
plt.bar(index, df["speedup_basic"], width=bar_width, label="Speedup GemmBasic", color="royalblue")
plt.bar([i + bar_width for i in index], df["speedup_streamk"], width=bar_width, label="Speedup GemmStreamK", color="seagreen")

# 添加标题和轴标签
plt.title("Basic/torch (B) vs StreamK/torch (G)", fontsize=18, fontweight='bold')
plt.xlabel("Shape Index", fontsize=14)
plt.ylabel("Speedup", fontsize=14)

# 调整图例位置和样式
# plt.legend(title="Method", title_fontsize='13', loc='upper left', fontsize='12', frameon=True)

# 设置x轴的刻度
# plt.xticks([i + bar_width/2 for i in index], index)

# 显示图表
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df_filtered = df[(df["speedup_basic"] > 1) | (df["speedup_streamk"] > 1)]
df_filtered = df_filtered.sort_values(by="m", ascending=True)

if not df_filtered.empty:
    # 计算 FLOPs
    df_filtered['flops'] = df_filtered['m'] * 1536 * 6144 * 2

    plt.figure(figsize=(12, 4))
    index = range(len(df_filtered))

    bar_width = 0.35
    plt.bar(index, df_filtered["speedup_basic"], width=bar_width, label="Speedup GemmBasic", color="royalblue")
    plt.bar([i + bar_width for i in index], df_filtered["speedup_streamk"], width=bar_width, label="Speedup GemmStreamK", color="seagreen")

    plt.title("Speedup > 1 with FLOPs", fontsize=18, fontweight='bold')
    plt.xlabel("m", fontsize=14)
    plt.ylabel("Speedup", fontsize=14)
    plt.legend(title_fontsize='13', loc='upper right', fontsize='12', frameon=True)
    plt.legend(title_fontsize='13', loc='upper left', fontsize='12', frameon=True)

    m_values = df_filtered["m"].tolist()  # 获取 m 值作为 x 轴标签
    plt.xticks([i + bar_width / 2 for i in index], m_values, rotation=45, ha="right")

    ax2 = plt.gca().twinx()
    ax2.plot(index, df_filtered["flops"], color='red', marker='o', label="FLOPs", linestyle='--')
    ax2.set_ylabel("FLOPs", fontsize=14)
    ax2.legend(loc='upper right')


    plt.tight_layout()
    plt.show()
else:
    print("No data points with speedup > 1.")

# %%
poor_performance = df[(df['speedup_cutlass'] < 0.8)]
print(poor_performance[['m', 'speedup_cutlass']])
# Out:
#          m  speedup_cutlass
# 0     1848         0.260216
# 1     3072         0.340573
# 2     4004         0.394240
# 11    4158         0.397166
# 15    4312         0.415478
# ..     ...              ...
# 463  21216         0.738820
# 136  21312         0.733058
# 511  22724         0.787237
# 522  30420         0.793697
# 446  34255         0.675522
#
# [96 rows x 2 columns]

# %%
better_performance = df[(df['speedup_cutlass'] > 1.2)]
print(better_performance[['m', 'speedup_cutlass']])
# Out:
#          m  speedup_cutlass
# 602  14938         1.203386
# 309  14950         1.211588
# 7    14976         1.314405
# 627  16016         1.203389
# 112  16128         1.218475
# ..     ...              ...
# 363  34485         1.283256
# 519  34496         1.281019
# 287  34560         1.289545
# 407  34560         1.288600
# 664  35880         1.236118
#
# [109 rows x 2 columns]
